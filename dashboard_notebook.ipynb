# %% [markdown]
# __Covid19 Dashboard__

# %% [markdown]
# In this notebook I'll build an interactive dashboard for COVID19. Firstly, let's prepare the data before visualizing

# %%
# loading confirmed cases, deaths and recoveries from GitHub repository
import pandas as pd
confirmed_cases_data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths_data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recoveries_data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
confirmed_cases_data.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...   8/3/22  \
# 0        0        0        0        0        0        0  ...   186393
# 1        0        0        0        0        0        0  ...   314561
# 2        0        0        0        0        0        0  ...   267777
# 3        0        0        0        0        0        0  ...    45793
# 4        0        0        0        0        0        0  ...   102301
# 5        0        0        0        0        0        0  ...       11
# 6        0        0        0        0        0        0  ...     8773
# 7        0        0        0        0        0        0  ...  9560307
# 8        0        0        0        0        0        0  ...   426799
# 9        0        0        0        0        0        0  ...   193557
#
#     8/4/22   8/5/22   8/6/22   8/7/22   8/8/22   8/9/22  8/10/22  8/11/22  \
# 0   186697   187037   187109   187442   187685   187966   188202   188506
# 1   315337   316145   316976   317514   317681   318638   319444   320086
# 2   267902   268033   268141   268254   268356   268478   268584   268718
# 3    45793    45793    45793    45793    45793    45793    45899    45899
# 4   102301   102636   102636   102636   102636   102636   102636   102636
# 5       11       11       11       11       11       11       11       11
# 6     8773     8773     8773     8787     8809     8809     8809     8809
# 7  9560307  9560307  9560307  9602534  9602534  9602534  9602534  9602534
# 8   426799   426799   426799   426799   428648   428648   428648   428648
# 9   194215   194705   195115   195621   196098   196642   197094   197561
#
#    8/12/22
# 0   188704
# 1   320781
# 2   268866
# 3    45899
# 4   102636
# 5       11
# 6     8820
# 7  9602534
# 8   428648
# 9   197883
#
# [10 rows x 938 columns]

# %%
deaths_data.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  8/3/22  8/4/22  \
# 0        0        0        0        0        0        0  ...    7752    7752
# 1        0        0        0        0        0        0  ...    3551    3554
# 2        0        0        0        0        0        0  ...    6876    6877
# 3        0        0        0        0        0        0  ...     154     154
# 4        0        0        0        0        0        0  ...    1912    1912
# 5        0        0        0        0        0        0  ...       0       0
# 6        0        0        0        0        0        0  ...     144     144
# 7        0        0        0        0        0        0  ...  129369  129369
# 8        0        0        0        0        0        0  ...    8635    8635
# 9        0        0        0        0        0        0  ...     100     100
#
#    8/5/22  8/6/22  8/7/22  8/8/22  8/9/22  8/10/22  8/11/22  8/12/22
# 0    7752    7752    7752    7753    7753     7753     7755     7755
# 1    3557    3560    3563    3566    3566     3567     3568     3569
# 2    6878    6878    6878    6878    6878     6878     6878     6878
# 3     154     154     154     154     154      154      154      154
# 4    1917    1917    1917    1917    1917     1917     1917     1917
# 5       0       0       0       0       0        0        0        0
# 6     144     144     144     144     144      144      144      144
# 7  129369  129369  129440  129440  129440   129440   129440   129440
# 8    8635    8635    8635    8637    8637     8637     8637     8637
# 9     101     101     102     106     107      108      109      110
#
# [10 rows x 938 columns]

# %%
recoveries_data.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#       date  recoveries
# 0  1/22/20           0
# 1  1/22/20           0
# 2  1/22/20           0
# 3  1/22/20           0
# 4  1/22/20           0
# 5  1/22/20           0
# 6  1/22/20           0
# 7  1/22/20           0
# 8  1/22/20           0
# 9  1/22/20           0

# %% [markdown]
# Well, cases are not convinently distributed (they are in wide format). It will be transformed into a long format in the next section

# %%
confirmed_cases_data = pd.melt(confirmed_cases_data, id_vars=confirmed_cases_data.columns[:4], value_vars=confirmed_cases_data.columns[4:], var_name='date', value_name='confirmed')
deaths_data = pd.melt(deaths_data, id_vars=deaths_data.columns[:4], value_vars=deaths_data.columns[4:], var_name='date', value_name='deaths')
recoveries_data = pd.melt(recoveries_data, id_vars=recoveries_data.columns[:4], value_vars=recoveries_data.columns[4:], var_name='date', value_name='recoveries')

# %%
confirmed_cases_data.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#       date  confirmed
# 0  1/22/20          0
# 1  1/22/20          0
# 2  1/22/20          0
# 3  1/22/20          0
# 4  1/22/20          0
# 5  1/22/20          0
# 6  1/22/20          0
# 7  1/22/20          0
# 8  1/22/20          0
# 9  1/22/20          0

# %%
deaths_data.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#       date  deaths
# 0  1/22/20       0
# 1  1/22/20       0
# 2  1/22/20       0
# 3  1/22/20       0
# 4  1/22/20       0
# 5  1/22/20       0
# 6  1/22/20       0
# 7  1/22/20       0
# 8  1/22/20       0
# 9  1/22/20       0

# %%
recoveries_data.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#       date  recoveries
# 0  1/22/20           0
# 1  1/22/20           0
# 2  1/22/20           0
# 3  1/22/20           0
# 4  1/22/20           0
# 5  1/22/20           0
# 6  1/22/20           0
# 7  1/22/20           0
# 8  1/22/20           0
# 9  1/22/20           0

# %% [markdown]
# According to the source, there are some problems with Canada. Let's have a look

# %%
confirmed_cases_data[confirmed_cases_data['Country/Region']=='Canada']
# Out:
#                 Province/State Country/Region      Lat      Long     date  \
# 40                     Alberta         Canada  53.9333 -116.5765  1/22/20
# 41            British Columbia         Canada  53.7267 -127.6476  1/22/20
# 42            Diamond Princess         Canada   0.0000    0.0000  1/22/20
# 43              Grand Princess         Canada   0.0000    0.0000  1/22/20
# 44                    Manitoba         Canada  53.7609  -98.8139  1/22/20
# ...                        ...            ...      ...       ...      ...
# 265956    Prince Edward Island         Canada  46.5107  -63.4168  8/12/22
# 265957                  Quebec         Canada  52.9399  -73.5491  8/12/22
# 265958  Repatriated Travellers         Canada      NaN       NaN  8/12/22
# 265959            Saskatchewan         Canada  52.9399 -106.4509  8/12/22
# 265960                   Yukon         Canada  64.2823 -135.0000  8/12/22
#
#         confirmed
# 40              0
# 41              0
# 42              0
# 43              0
# 44              0
# ...           ...
# 265956      48027
# 265957    1161491
# 265958         13
# 265959     140291
# 265960       4771
#
# [14944 rows x 6 columns]

# %%
deaths_data[deaths_data['Country/Region']=='Canada']
# Out:
#                 Province/State Country/Region      Lat      Long     date  \
# 40                     Alberta         Canada  53.9333 -116.5765  1/22/20
# 41            British Columbia         Canada  53.7267 -127.6476  1/22/20
# 42            Diamond Princess         Canada   0.0000    0.0000  1/22/20
# 43              Grand Princess         Canada   0.0000    0.0000  1/22/20
# 44                    Manitoba         Canada  53.7609  -98.8139  1/22/20
# ...                        ...            ...      ...       ...      ...
# 265956    Prince Edward Island         Canada  46.5107  -63.4168  8/12/22
# 265957                  Quebec         Canada  52.9399  -73.5491  8/12/22
# 265958  Repatriated Travellers         Canada      NaN       NaN  8/12/22
# 265959            Saskatchewan         Canada  52.9399 -106.4509  8/12/22
# 265960                   Yukon         Canada  64.2823 -135.0000  8/12/22
#
#         deaths
# 40           0
# 41           0
# 42           0
# 43           0
# 44           0
# ...        ...
# 265956      51
# 265957   16116
# 265958       0
# 265959    1438
# 265960      30
#
# [14944 rows x 6 columns]

# %%
recoveries_data[recoveries_data['Country/Region']=='Canada']
# Out:
#        Province/State Country/Region      Lat      Long     date  recoveries
# 40                NaN         Canada  56.1304 -106.3468  1/22/20           0
# 310               NaN         Canada  56.1304 -106.3468  1/23/20           0
# 580               NaN         Canada  56.1304 -106.3468  1/24/20           0
# 850               NaN         Canada  56.1304 -106.3468  1/25/20           0
# 1120              NaN         Canada  56.1304 -106.3468  1/26/20           0
# ...               ...            ...      ...       ...      ...         ...
# 250870            NaN         Canada  56.1304 -106.3468   8/8/22           0
# 251140            NaN         Canada  56.1304 -106.3468   8/9/22           0
# 251410            NaN         Canada  56.1304 -106.3468  8/10/22           0
# 251680            NaN         Canada  56.1304 -106.3468  8/11/22           0
# 251950            NaN         Canada  56.1304 -106.3468  8/12/22           0
#
# [934 rows x 6 columns]

# %% [markdown]
# The problem is that in Deaths/Confirmed cases datasets Canada's data is represented with provinces while in Recoveries provinces are not mentioned. To continue working on the data, this possible conflict must be resolved

# %%
# summarizing numbers in Canada confirmed cases and deaths
confirmed_cases_canada = confirmed_cases_data[confirmed_cases_data['Country/Region']=='Canada'].groupby('date').sum()[['confirmed']]
deaths_canada = deaths_data[deaths_data['Country/Region']=='Canada'].groupby('date').sum()[['deaths']]

# extracting Canada recoveries (columns)
recoveries_canada = recoveries_data[recoveries_data['Country/Region']=='Canada']
template_updated_canada = recoveries_canada[recoveries_canada.columns[:-1]].reset_index(drop=True)

# joining deaths and confirmed cases with teh columns
confirmed_cases_canada = template_updated_canada.merge(confirmed_cases_canada, how='inner', left_on='date', right_index=True)
deaths_canada = template_updated_canada.merge(deaths_canada, how='inner', left_on='date', right_index=True)

# altering the original deaths and confirmed cases to resolve the problem
confirmed_cases_data = confirmed_cases_data[confirmed_cases_data['Country/Region']!='Canada'].append(confirmed_cases_canada)
deaths_data = deaths_data[deaths_data['Country/Region']!='Canada'].append(deaths_canada)

# %% [markdown]
# The problem was resolved by summarizing deaths and confirmed cases for the whole country by date and merging with recoveries values

# %% [markdown]
# Then all the three tables will be cobined into one table

# %%
combined_data = confirmed_cases_data.merge(deaths_data, how='inner', on=['Country/Region', 'Province/State', 'date', 'Lat', 'Long']).merge(recoveries_data, how='inner', on=['Country/Region', 'Province/State', 'date', 'Lat', 'Long'])
combined_data.sample(15)
# Out:
#          Province/State Country/Region        Lat        Long      date  \
# 107617              NaN        Moldova  47.411600   28.369900    3/4/21
# 142878            Hubei          China  30.975600  112.270700   7/16/21
# 51897               NaN          Libya  26.335100   17.228331    8/5/20
# 162898  New South Wales      Australia -33.868800  151.209300   9/30/21
# 17556               NaN           Iran  32.427908   53.688046   3/28/20
# 53521               NaN       Paraguay -23.442500  -58.443800   8/11/20
# 185920          Shaanxi          China  35.191700  108.870100  12/26/21
# 132258              NaN        Vietnam  14.058324  108.277199    6/5/21
# 96836               NaN   Sierra Leone   8.460555  -11.779889   1/22/21
# 24451               NaN          Malta  35.937500   14.375400   4/23/20
# 21241               NaN      Guatemala  15.783500  -90.230800   4/11/20
# 97796               NaN        Georgia  42.315400   43.356900   1/26/21
# 207063              NaN        Denmark  56.263900    9.501800   3/16/22
# 16718         Greenland        Denmark  71.706900  -42.604300   3/25/20
# 122417              NaN        Nigeria   9.082000    8.675300   4/29/21
#
#         confirmed  deaths  recoveries
# 107617     191197    4049      168801
# 142878      68188    4512       63648
# 51897        4475      99         640
# 162898      63212     406           0
# 17556       35408    2517       11679
# 53521        7519      86        5326
# 185920       1239       3           0
# 132258       8580      53        3310
# 96836        3093      77        2166
# 24451         445       3         204
# 21241         137       3          19
# 97796      254822    3096      244446
# 207063    2978029    5257           0
# 16718           6       0           2
# 122417     165055    2063      155041

# %% [markdown]
# In addition, we'll add population data from a different table

# %%
# loading the data
population_data = pd.read_csv('population_by_country_2020.csv')
population_data.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# 2        83 %      4.25 %
# 3        56 %      3.51 %
# 4        35 %      2.83 %

# %% [markdown]
# Before merging on countries, we must check if there are countries in both or one of the tables that have different names

# %%
for our_country in combined_data['Country/Region'].unique():
    if our_country not in population_data['Country (or dependency)'].unique():
        print(our_country)
# Out:
# Antarctica
# Burma
# Congo (Brazzaville)
# Congo (Kinshasa)
# Cote d'Ivoire
# Czechia
# Diamond Princess
# Korea, North
# Korea, South
# Kosovo
# MS Zaandam
# Saint Kitts and Nevis
# Saint Vincent and the Grenadines
# Sao Tome and Principe
# Summer Olympics 2020
# Taiwan*
# US
# West Bank and Gaza
# Winter Olympics 2022

# %%
combined_data = combined_data.drop(combined_data[combined_data['Country/Region']=='Winter Olympics 2022'].index)

# %%
problem_country={
    'Congo (Brazzaville)': 'Congo',
    'Congo (Kinshasa)': 'Congo',
    "Cote d'Ivoire": "Côte d'Ivoire",
    'Czechia': 'Czech Republic (Czechia)',
    'Korea, South': 'South Korea',
    'Saint Vincent and the Grenadines': 'St. Vincent & Grenadines',
    'Taiwan*': 'Taiwan',
    'US': 'United States',
    'West Bank and Gaza': 'Israel',
    'Saint Kitts and Nevis': 'Saint Kitts & Nevis',
    'Burma': 'Myanmar',
    'Sao Tome and Principe': 'Sao Tome & Principe'
}

#replaing 
combined_data['Country/Region']=combined_data['Country/Region'].replace(problem_country)
combined_data.index = combined_data['Country/Region']

# %%
combined_data.head(10)
# Out:
#                                    Province/State       Country/Region  \
# Country/Region
# Afghanistan                                   NaN          Afghanistan
# Albania                                       NaN              Albania
# Algeria                                       NaN              Algeria
# Andorra                                       NaN              Andorra
# Angola                                        NaN               Angola
# Antarctica                                    NaN           Antarctica
# Antigua and Barbuda                           NaN  Antigua and Barbuda
# Argentina                                     NaN            Argentina
# Armenia                                       NaN              Armenia
# Australia            Australian Capital Territory            Australia
#
#                           Lat        Long     date  confirmed  deaths  \
# Country/Region
# Afghanistan          33.93911   67.709953  1/22/20          0       0
# Albania              41.15330   20.168300  1/22/20          0       0
# Algeria              28.03390    1.659600  1/22/20          0       0
# Andorra              42.50630    1.521800  1/22/20          0       0
# Angola              -11.20270   17.873900  1/22/20          0       0
# Antarctica          -71.94990   23.347000  1/22/20          0       0
# Antigua and Barbuda  17.06080  -61.796400  1/22/20          0       0
# Argentina           -38.41610  -63.616700  1/22/20          0       0
# Armenia              40.06910   45.038200  1/22/20          0       0
# Australia           -35.47350  149.012400  1/22/20          0       0
#
#                      recoveries
# Country/Region
# Afghanistan                   0
# Albania                       0
# Algeria                       0
# Andorra                       0
# Angola                        0
# Antarctica                    0
# Antigua and Barbuda           0
# Argentina                     0
# Armenia                       0
# Australia                     0

# %% [markdown]
# Merging all the data just in case

# %%
copy_data_comb = combined_data.copy(deep=True)
copy_data_pop = population_data.copy(deep=True)

# %%
copy_data_pop.index = copy_data_pop['Country (or dependency)']
final_data = copy_data_comb.merge(copy_data_pop, how='inner', right_index=True, left_index=True)
final_data.sample(10)
# Out:
#                 Province/State   Country/Region        Lat        Long  \
# New Zealand       Cook Islands      New Zealand -21.236700 -159.777700
# Cuba                       NaN             Cuba  21.521757  -77.781167
# Pakistan                   NaN         Pakistan  30.375300   69.345100
# Malaysia                   NaN         Malaysia   4.210484  101.975766
# Monaco                     NaN           Monaco  43.733300    7.416700
# Belgium                    NaN          Belgium  50.833300    4.469936
# Greece                     NaN           Greece  39.074200   21.824300
# Solomon Islands            NaN  Solomon Islands  -9.645700  160.156200
# China                Hong Kong            China  22.300000  114.200000
# China                  Tianjin            China  39.305400  117.323000
#
#                      date  confirmed  deaths  recoveries  \
# New Zealand       4/14/21          0       0           0
# Cuba              6/12/22    1105612    8529           0
# Pakistan         12/20/20     458968    9392      409085
# Malaysia          4/26/22    4436912   35520           0
# Monaco             1/6/21        978       3         773
# Belgium            8/1/20      69402    9845       17573
# Greece             5/2/21     346422   10453       93764
# Solomon Islands   11/2/20         13       0           4
# China             6/20/21      11886     210       11614
# China              5/6/20        190       3         186
#
#                 Country (or dependency)  Population (2020) Yearly Change  \
# New Zealand                 New Zealand            4829021        0.82 %
# Cuba                               Cuba           11325391       -0.06 %
# Pakistan                       Pakistan          221612785        2.00 %
# Malaysia                       Malaysia           32436963        1.30 %
# Monaco                           Monaco              39290        0.71 %
# Belgium                         Belgium           11598451        0.44 %
# Greece                           Greece           10413936       -0.48 %
# Solomon Islands         Solomon Islands             689671        2.55 %
# China                             China         1440297825        0.39 %
# China                             China         1440297825        0.39 %
#
#                  Net Change  Density (P/Km²)  Land Area (Km²)  Migrants (net)  \
# New Zealand           39170               18           263310         14881.0
# Cuba                  -6867              106           106440        -14400.0
# Pakistan            4327022              287           770880       -233379.0
# Malaysia             416222               99           328550         50000.0
# Monaco                  278            26337                1             NaN
# Belgium               50295              383            30280         48000.0
# Greece               -50401               81           128900        -16000.0
# Solomon Islands       17061               25            27990         -1600.0
# China               5540090              153          9388211       -348399.0
# China               5540090              153          9388211       -348399.0
#
#                 Fert. Rate Med. Age Urban Pop % World Share
# New Zealand            1.9       38        87 %      0.06 %
# Cuba                   1.6       42        78 %      0.15 %
# Pakistan               3.6       23        35 %      2.83 %
# Malaysia               2.0       30        78 %      0.42 %
# Monaco                N.A.     N.A.        N.A.      0.00 %
# Belgium                1.7       42        98 %      0.15 %
# Greece                 1.3       46        85 %      0.13 %
# Solomon Islands        4.4       20        23 %      0.01 %
# China                  1.7       38        61 %     18.47 %
# China                  1.7       38        61 %     18.47 %

# %%
# saving data
final_data.to_csv('Covid_and_pop.csv')
combined_data.to_csv('Fin_covid_data.csv')

# %% [markdown]
# Time to build the dash board
